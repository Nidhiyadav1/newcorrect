# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhiyadav1/newcorrect/blob/main/yolo11s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
import cv2
from roboflow import Roboflow
rf = Roboflow(api_key="HktJUpAVTxx1yQmsOIhS")
project = rf.workspace("diplomatic").project("heridal-zeyw0")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 11.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Heridal-2 in yolov11:: 100%|██████████| 1977/1977 [00:01<00:00, 1447.61it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolo11s-seg.pt')
# Out:
# ...
# 100%|██████████| 19.7M/19.7M [00:00<00:00, 199MB/s]

# %%
results = model.train(task = 'segment', mode = 'train', data = '/content/Heridal-2/data.yaml', epochs = 50)
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model=yolo11s-seg.pt epochs=50 imgsz=640
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolo11s.pt')
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 197MB/s]

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model=yolo11s.pt epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/yolo11s_trained.pt

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model=yolo11s.pt epochs=120 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp runs/detect/train2/weights/best.pt/content/drive/MyDrive/yolo11s_trained.pt
# Out:
# cp: missing destination file operand after 'runs/detect/train2/weights/best.pt/content/drive/MyDrive/yolo11s_trained.pt'
# Try 'cp --help' for more information.

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/Heridal-2/valid/images/train_BRA_1029_JPG.rf.12e795f0414b1c8840f4072d7865f0dc.jpg
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Heridal-2/valid/images/train_BRA_1029_JPG.rf.12e795f0414b1c8840f4072d7865f0dc.jpg: 640x640 1 Person, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 147.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import display
from PIL import Image

image_path = "/content/runs/detect/predict/train_BRA_1029_JPG.rf.12e795f0414b1c8840f4072d7865f0dc.jpg"  # Change to your output image name
display(Image.open(image_path))

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/Heridal-2/valid/images/train_BRK_2002_JPG.rf.93adafeebfe979a2c86215433ca1c578.jpg
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Heridal-2/valid/images/train_BRK_2002_JPG.rf.93adafeebfe979a2c86215433ca1c578.jpg: 640x640 2 Persons, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 143.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import display
from PIL import Image

image_path = "/content/runs/detect/predict2/train_BRK_2002_JPG.rf.93adafeebfe979a2c86215433ca1c578.jpg"  # Change to your output image name
display(Image.open(image_path))

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/Heridal-2/valid/images/train_MED_3028_JPG.rf.3707784153b722b9135b1921acead69d.jpg
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /content/Heridal-2/valid/images/train_MED_3028_JPG.rf.3707784153b722b9135b1921acead69d.jpg: 640x640 6 Persons, 15.6ms
# Speed: 3.7ms preprocess, 15.6ms inference, 144.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import display
from PIL import Image

image_path = "/content/runs/detect/predict3/train_MED_3028_JPG.rf.3707784153b722b9135b1921acead69d.jpg"  # Change to your output image name
display(Image.open(image_path))
